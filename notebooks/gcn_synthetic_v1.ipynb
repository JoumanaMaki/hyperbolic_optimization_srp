# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import networkx as nx

sys.path.append("..")
from models.gcn.gcn_3layer import GCN
from utils.seed_everything import seed_everything

# %%
seed_everything()

# %%
balanced_tree = nx.balanced_tree(r=3, h=3)

# %%
nx.draw(nx.balanced_tree(
    r=3, # branching factor
    h=3  # height
))
